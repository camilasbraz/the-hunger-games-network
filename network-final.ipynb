# %%
import sys
import os

import spacy
from spacy.tokens import Doc
from spacy import displacy

import re 
import pandas as pd

# %%
# pip install -U pip setuptools wheel
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#                                               0.0/12.8 MB ? eta -:--:--
#                                               0.1/12.8 MB 3.6 MB/s eta 0:00:04
#      -                                        0.4/12.8 MB 5.5 MB/s eta 0:00:03
#      --                                       0.9/12.8 MB 7.1 MB/s eta 0:00:02
#      ----                                     1.4/12.8 MB 8.3 MB/s eta 0:00:02
#      ------                                   2.0/12.8 MB 8.9 MB/s eta 0:00:02
#      -------                                  2.5/12.8 MB 9.4 MB/s eta 0:00:02
#      ---------                                3.0/12.8 MB 9.7 MB/s eta 0:00:02
#      -----------                              3.6/12.8 MB 9.9 MB/s eta 0:00:01
#      ------------                             4.1/12.8 MB 10.5 MB/s eta 0:00:01
#      --------------                           4.7/12.8 MB 10.4 MB/s eta 0:00:01
#      ----------------                         5.3/12.8 MB 10.5 MB/s eta 0:00:01
#      -----------------                        5.7/12.8 MB 10.8 MB/s eta 0:00:01
#      -------------------                      6.1/12.8 MB 10.3 MB/s eta 0:00:01
#      -------------------                      6.2/12.8 MB 9.6 MB/s eta 0:00:01
#      ----------------------                   7.2/12.8 MB 10.5 MB/s eta 0:00:01
#      ------------------------                 7.8/12.8 MB 10.6 MB/s eta 0:00:01
#      --------------------------               8.4/12.8 MB 10.7 MB/s eta 0:00:01
#      ---------------------------              8.9/12.8 MB 10.7 MB/s eta 0:00:01
#      -----------------------------            9.4/12.8 MB 10.8 MB/s eta 0:00:01
#      ------------------------------          10.0/12.8 MB 10.8 MB/s eta 0:00:01
#      --------------------------------        10.5/12.8 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------       11.1/12.8 MB 11.5 MB/s eta 0:00:01
#      -----------------------------------     11.6/12.8 MB 11.5 MB/s eta 0:00:01
#      -------------------------------------   12.2/12.8 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  12.7/12.8 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.25.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.10)
# Requirement already satisfied: jinja2 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.0)
# Requirement already satisfied: colorama in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\camil\documents\github\0the-hunger-games-network\venv\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# appending a path
sys.path.append('lib/utils/')
 
# importing required module
from functions import ner, get_ne_list_per_sentence, filter_entity, create_relationships

# %% [markdown]
# ## Load Books

# %%
# Get all book files in the data directory
all_books = [b for b in os.scandir('books') if b.name.endswith('.pdf')]

# Sort dir entries by name
all_books.sort(key=lambda x: x.name)
all_books
# Out:
# [<DirEntry '0 - Hunger Games.pdf'>,
#  <DirEntry '1 - Catching Fire.pdf'>,
#  <DirEntry '2 - Mocking Jay.pdf'>]

# %%
# Load the Spacy model
nlp = spacy.load("en_core_web_sm")

# Process the selected books
book_docs = []
for book in all_books:
    print(book.path)
    # Specify the starting page
    if book.name == '0 - Hunger Games.pdf' or book.name == '1 - Catching Fire.pdf':
        start_page = 3  # Hunger Games, Catching Fire
    else:
        start_page = 12  # Mockingjay
    
    book_doc = ner(book.path, start_page, nlp)
    book_docs.append(book_doc)

# Combine the individual book documents into a single document
combined_doc = Doc.from_docs(book_docs)
# Out:
# books\0 - Hunger Games.pdf
# books\1 - Catching Fire.pdf
# books\2 - Mocking Jay.pdf

# %%
# Visualize identified entities
displacy.render(combined_doc[0:2000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">PART I</br>&quot;THE TRIBUTES&quot;</br>3When I wake up, the other side of the bed is cold. My fin-</br>gers stretch out, seeking
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s warmth but finding only the</br>rough canvas cover of the mattress. She must have had bad</br>dreams and climbed in with our mother. Of course, she did.</br>This is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the reaping.</br>I prop myself up on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  elbow. There’s enough light in the</br>bedroom to see them. My little sister,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , curled up on her</br>side, cocooned in my mother’s body, their cheeks pressed to-</br>gether. In sleep, my mother looks younger, still worn but not</br>so beaten-down.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s face is as fresh as a raindrop, as lovely</br>as the primrose for which she was named. My mother was</br>very beautiful once, too. Or so they tell me.</br>Sitting at Prim’s knees, guarding her, is the world’s ugliest</br>cat. Mashed-in nose,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of one ear missing, eyes the color of</br>rotting squash. Prim named him
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buttercup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , insisting that his</br>muddy yellow coat matched the bright flower. I le hates me.</br>Or at least distrusts me. Even though it was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I think</br>he still remembers how I tried to drown him in a bucket when</br>
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  brought him home. Scrawny kitten, belly swollen with</br>worms, crawling with fleas. The last thing I needed was</br>another mouth to feed. But
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  begged so hard, cried even, I</br>had to let him stay. It turned out okay. My mother got rid of</br>4the vermin and he’s a born mouser. Even catches the occa-</br>sional rat. Sometimes, when I clean a kill, I feed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buttercup
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the</br>entrails. He has stopped hissing at me.</br>Entrails. No hissing. This is the closest we will ever come to</br>love.</br>I swing my legs off the bed and slide into my hunting boots.</br>Supple leather that has molded to my feet. I pull on trousers, a</br>shirt, tuck my long dark braid up into a cap, and grab my fo-</br>rage bag. On the table, under a wooden bowl to protect it from</br>hungry rats and cats alike, sits a perfect little goat cheese</br>wrapped in basil leaves.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s gift to me on reaping day. I put</br>the cheese carefully in my pocket as I slip outside.</br>Our part of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     District 12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , nicknamed the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Seam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is usually</br>crawling with coal miners heading out to the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  shift at</br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this hour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# . Men and women with hunched shoulders, swollen</br>knuckles, many who have long since stopped trying to scrub</br>the coal dust out of their broken nails, the lines of their sun-</br>ken faces. But
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the black cinder streets are empty. Shut-</br>ters on the squat gray houses are closed. The reaping isn’t un-</br>til
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINA

# %% [markdown]
# ## Load Characters

# %%
# Read characters
character_df = pd.read_csv("characters.csv")

# Remove brackets and text within brackets
character_df['character'] = character_df['character'].apply(lambda x: re.sub("[\(].*?[\)]", "", x)) 
character_df['character_firstname'] = character_df['character'].apply(lambda x: x.split(' ', 1)[0])

pd.set_option('display.max_rows', None)
character_df
# Out:
#                                      book  \
# 0       Category:Catching Fire characters
# 1       Category:Catching Fire characters
# 2       Category:Catching Fire characters
# 3       Category:Catching Fire characters
# 4       Category:Catching Fire characters
# 5       Category:Catching Fire characters
# 6       Category:Catching Fire characters
# 7       Category:Catching Fire characters
# 8       Category:Catching Fire characters
# 9       Category:Catching Fire characters
# 10      Category:Catching Fire characters
# 11      Category:Catching Fire characters
# 12      Category:Catching Fire characters
# 13      Category:Catching Fire characters
# 14      Category:Catching Fire characters
# 15      Category:Catching Fire characters
# 16      Category:Catching Fire characters
# 17      Category:Catching Fire characters
# 18      Category:Catching Fire characters
# 19      Category:Catching Fire characters
# 20      Category:Catching Fire characters
# 21      Category:Catching Fire characters
# 22      Category:Catching Fire characters
# 23      Category:Catching Fire characters
# 24      Category:Catching Fire characters
# 25      Category:Catching Fire characters
# 26      Category:Catching Fire characters
# 27      Category:Catching Fire characters
# 28      Category:Catching Fire characters
# 29      Category:Catching Fire characters
# 30      Category:Catching Fire characters
# 31      Category:Catching Fire characters
# 32      Category:Catching Fire characters
# 33      Category:Catching Fire characters
# 34      Category:Catching Fire characters
# 35      Category:Catching Fire characters
# 36      Category:Catching Fire characters
# 37      Category:Catching Fire characters
# 38      Category:Catching Fire characters
# 39      Category:Catching Fire characters
# 40      Category:Catching Fire characters
# 41      Category:Catching Fire characters
# 42      Category:Catching Fire characters
# 43      Category:Catching Fire characters
# 44      Category:Catching Fire characters
# 45      Category:Catching Fire characters
# 46      Category:Catching Fire characters
# 47      Category:Catching Fire characters
# 48      Category:Catching Fire characters
# 49      Category:Catching Fire characters
# 50      Category:Catching Fire characters
# 51      Category:Catching Fire characters
# 52      Category:Catching Fire characters
# 53      Category:Catching Fire characters
# 54      Category:Catching Fire characters
# 55      Category:Catching Fire characters
# 56      Category:Catching Fire characters
# 57      Category:Catching Fire characters
# 58      Category:Catching Fire characters
# 59      Category:Catching Fire characters
# 60      Category:Catching Fire characters
# 61      Category:Catching Fire characters
# 62      Category:Catching Fire characters
# 63      Category:Catching Fire characters
# 64      Category:Catching Fire characters
# 65      Category:Catching Fire characters
# 66      Category:Catching Fire characters
# 67      Category:Catching Fire characters
# 68         Category:Mockingjay characters
# 69         Category:Mockingjay characters
# 70         Category:Mockingjay characters
# 71         Category:Mockingjay characters
# 72         Category:Mockingjay characters
# 73         Category:Mockingjay characters
# 74         Category:Mockingjay characters
# 75         Category:Mockingjay characters
# 76         Category:Mockingjay characters
# 77         Category:Mockingjay characters
# 78         Category:Mockingjay characters
# 79         Category:Mockingjay characters
# 80         Category:Mockingjay characters
# 81         Category:Mockingjay characters
# 82         Category:Mockingjay characters
# 83         Category:Mockingjay characters
# 84         Category:Mockingjay characters
# 85         Category:Mockingjay characters
# 86         Category:Mockingjay characters
# 87         Category:Mockingjay characters
# 88         Category:Mockingjay characters
# 89         Category:Mockingjay characters
# 90         Category:Mockingjay characters
# 91         Category:Mockingjay characters
# 92         Category:Mockingjay characters
# 93         Category:Mockingjay characters
# 94         Category:Mockingjay characters
# 95         Category:Mockingjay characters
# 96         Category:Mockingjay characters
# 97         Category:Mockingjay characters
# 98         Category:Mockingjay characters
# 99         Category:Mockingjay characters
# 100        Category:Mockingjay characters
# 101        Category:Mockingjay characters
# 102        Category:Mockingjay characters
# 103        Category:Mockingjay characters
# 104        Category:Mockingjay characters
# 105        Category:Mockingjay characters
# 106        Category:Mockingjay characters
# 107        Category:Mockingjay characters
# 108        Category:Mockingjay characters
# 109        Category:Mockingjay characters
# 110        Category:Mockingjay characters
# 111        Category:Mockingjay characters
# 112        Category:Mockingjay characters
# 113        Category:Mockingjay characters
# 114        Category:Mockingjay characters
# 115        Category:Mockingjay characters
# 116        Category:Mockingjay characters
# 117        Category:Mockingjay characters
# 118        Category:Mockingjay characters
# 119        Category:Mockingjay characters
# 120        Category:Mockingjay characters
# 121        Category:Mockingjay characters
# 122        Category:Mockingjay characters
# 123  Category:The Hunger Games characters
# 124  Category:The Hunger Games characters
# 125  Category:The Hunger Games characters
# 126  Category:The Hunger Games characters
# 127  Category:The Hunger Games characters
# 128  Category:The Hunger Games characters
# 129  Category:The Hunger Games characters
# 130  Category:The Hunger Games characters
# 131  Category:The Hunger Games characters
# 132  Category:The Hunger Games characters
# 133  Category:The Hunger Games characters
# 134  Category:The Hunger Games characters
# 135  Category:The Hunger Games characters
# 136  Category:The Hunger Games characters
# 137  Category:The Hunger Games characters
# 138  Category:The Hunger Games characters
# 139  Category:The Hunger Games characters
# 140  Category:The Hunger Games characters
# 141  Category:The Hunger Games characters
# 142  Category:The Hunger Games characters
# 143  Category:The Hunger Games characters
# 144  Category:The Hunger Games characters
# 145  Category:The Hunger Games characters
# 146  Category:The Hunger Games characters
# 147  Category:The Hunger Games characters
# 148  Category:The Hunger Games characters
# 149  Category:The Hunger Games characters
# 150  Category:The Hunger Games characters
# 151  Category:The Hunger Games characters
# 152  Category:The Hunger Games characters
# 153  Category:The Hunger Games characters
# 154  Category:The Hunger Games characters
# 155  Category:The Hunger Games characters
# 156  Category:The Hunger Games characters
# 157  Category:The Hunger Games characters
# 158  Category:The Hunger Games characters
# 159  Category:The Hunger Games characters
# 160  Category:The Hunger Games characters
# 161  Category:The Hunger Games characters
# 162  Category:The Hunger Games characters
# 163  Category:The Hunger Games characters
# 164  Category:The Hunger Games characters
# 165  Category:The Hunger Games characters
# 166  Category:The Hunger Games characters
# 167  Category:The Hunger Games characters
# 168  Category:The Hunger Games characters
# 169  Category:The Hunger Games characters
# 170  Category:The Hunger Games characters
# 171  Category:The Hunger Games characters
# 172  Category:The Hunger Games characters
# 173  Category:The Hunger Games characters
# 174  Category:The Hunger Games characters
# 175  Category:The Hunger Games characters
#
#                                       character character_firstname
# 0                            Haymitch Abernathy            Haymitch
# 1                                         Atala               Atala
# 2                                 Beetee Latier              Beetee
# 3                                        Blight              Blight
# 4                                        Bonnie              Bonnie
# 5                                       Bristel             Bristel
# 6                                        Brutus              Brutus
# 7                                     Buttercup           Buttercup
# 8                                      Cashmere            Cashmere
# 9                                       Cecelia             Cecelia
# 10                                        Chaff               Chaff
# 11                                        Cinna               Cinna
# 12                                         Cray                Cray
# 13                                 Annie Cresta               Annie
# 14                                       Darius              Darius
# 15                          District 10 female             District
# 16                            District 10 male             District
# 17                    District 2 female victor             District
# 18                 District 4 older male victor            District
# 19               District 4 younger male victor            District
# 20                           District 5 female             District
# 21                             District 5 male             District
# 22                           District 6 female             District
# 23                             District 6 male             District
# 24                           District 9 female             District
# 25                             District 9 male             District
# 26                                     Enobaria            Enobaria
# 27                             Katniss Everdeen             Katniss
# 28                                Mrs. Everdeen                Mrs.
# 29                            Primrose Everdeen            Primrose
# 30                                      Flavius             Flavius
# 31                            Caesar Flickerman              Caesar
# 32                                        Gloss               Gloss
# 33                               Gale Hawthorne                Gale
# 34                            Hazelle Hawthorne             Hazelle
# 35                               Posy Hawthorne                Posy
# 36                               Rory Hawthorne                Rory
# 37                               Vick Hawthorne                Vick
# 38                          Plutarch Heavensbee            Plutarch
# 39                                      Lavinia             Lavinia
# 40                                        Leevy               Leevy
# 41                                Johanna Mason             Johanna
# 42                                Peeta Mellark               Peeta
# 43                                   Morphlings          Morphlings
# 44                                      Octavia             Octavia
# 45                                Finnick Odair             Finnick
# 46                                       Portia              Portia
# 47                                       Purnia              Purnia
# 48                                       Ripper              Ripper
# 49                                 Rue's sister               Rue's
# 50                                   Greasy Sae              Greasy
# 51                                       Seeder              Seeder
# 52                              Coriolanus Snow          Coriolanus
# 53                                          Tax                 Tax
# 54                         Claudius Templesmith            Claudius
# 55                                         Thom                Thom
# 56                               Romulus Thread             Romulus
# 57                         Thresh's grandmother            Thresh's
# 58                              Thresh's sister            Thresh's
# 59   Category:Tributes in the 75th Hunger Games   Category:Tributes
# 60                                Effie Trinket               Effie
# 61                                        Twill               Twill
# 62                               Madge Undersee               Madge
# 63                               Mayor Undersee               Mayor
# 64             Unidentified District 11 citizen        Unidentified
# 65                                        Venia               Venia
# 66                                       Wiress              Wiress
# 67                                         Woof                Woof
# 68                           Haymitch Abernathy            Haymitch
# 69                                     Antonius            Antonius
# 70                                 Dr. Aurelius                 Dr.
# 71                                Beetee Latier              Beetee
# 72                                    Buttercup           Buttercup
# 73                                Fulvia Cardew              Fulvia
# 74                             Delly Cartwright               Delly
# 75                                       Castor              Castor
# 76                                    Alma Coin                Alma
# 77              Coriolanus Snow's granddaughter          Coriolanus
# 78                                     Cressida            Cressida
# 79                                 Annie Cresta               Annie
# 80                                       Dalton              Dalton
# 81                                       Darius              Darius
# 82                      District 13 head doctor            District
# 83                                         Eddy                Eddy
# 84                                Eddy's sister              Eddy's
# 85                                       Egeria              Egeria
# 86                                     Enobaria            Enobaria
# 87                             Katniss Everdeen             Katniss
# 88                                Mrs. Everdeen                Mrs.
# 89                            Primrose Everdeen            Primrose
# 90                                      Flavius             Flavius
# 91                            Caesar Flickerman              Caesar
# 92                   Greasy Sae's granddaughter              Greasy
# 93                               Gale Hawthorne                Gale
# 94                            Hazelle Hawthorne             Hazelle
# 95                               Posy Hawthorne                Posy
# 96                               Rory Hawthorne                Rory
# 97                          Plutarch Heavensbee            Plutarch
# 98                                        Homes               Homes
# 99                                      Jackson             Jackson
# 100        Katniss and Peeta Mellark's daughter             Katniss
# 101             Katniss and Peeta Mellark's son             Katniss
# 102                                      Leeg 1                Leeg
# 103                                      Leeg 2                Leeg
# 104                                       Leevy               Leevy
# 105                                        Lyme                Lyme
# 106                               Johanna Mason             Johanna
# 107                               Peeta Mellark               Peeta
# 108                                    Messalla            Messalla
# 109                                    Mitchell            Mitchell
# 110                                     Octavia             Octavia
# 111                               Finnick Odair             Finnick
# 112                            Commander Paylor           Commander
# 113                                      Portia              Portia
# 114                                      Pugnax              Pugnax
# 115                                  Greasy Sae              Greasy
# 116                             Coriolanus Snow          Coriolanus
# 117                        Claudius Templesmith            Claudius
# 118                                        Thom                Thom
# 119                                      Tigris              Tigris
# 120                               Effie Trinket               Effie
# 121                                       Venia               Venia
# 122                                        York                York
# 123                          Haymitch Abernathy            Haymitch
# 124                                       Atala               Atala
# 125                                   Buttercup           Buttercup
# 126                                        Cato                Cato
# 127                                       Cinna               Cinna
# 128                                       Clove               Clove
# 129                                Seneca Crane              Seneca
# 130                         District 10 female             District
# 131                           District 10 male             District
# 132                          District 3 female             District
# 133                            District 3 male             District
# 134                          District 4 female             District
# 135                            District 4 male             District
# 136                            District 5 male             District
# 137                          District 6 female             District
# 138                            District 6 male             District
# 139                          District 7 female             District
# 140                            District 7 male             District
# 141                          District 8 female             District
# 142                            District 8 male             District
# 143                          District 9 female             District
# 144                            District 9 male             District
# 145                            Katniss Everdeen             Katniss
# 146                               Mrs. Everdeen                Mrs.
# 147                           Primrose Everdeen            Primrose
# 148                                     Flavius             Flavius
# 149                           Caesar Flickerman              Caesar
# 150                                   "Foxface"           "Foxface"
# 151                                     Glimmer             Glimmer
# 152                              Gale Hawthorne                Gale
# 153                           Hazelle Hawthorne             Hazelle
# 154                              Rory Hawthorne                Rory
# 155                                     Lavinia             Lavinia
# 156                                       Lucia               Lucia
# 157                                      Martin              Martin
# 158                                      Marvel              Marvel
# 159                           First Mellark son               First
# 160                               Peeta Mellark               Peeta
# 161                                 Mr. Mellark                 Mr.
# 162                                Mrs. Mellark                Mrs.
# 163                                     Octavia             Octavia
# 164                                      Portia              Portia
# 165                                       Rooba               Rooba
# 166                                         Rue                 Rue
# 167                                  Greasy Sae              Greasy
# 168                             Coriolanus Snow          Coriolanus
# 169                        Claudius Templesmith            Claudius
# 170                                      Thresh              Thresh
# 171  Category:Tributes in the 74th Hunger Games   Category:Tributes
# 172                               Effie Trinket               Effie
# 173                              Madge Undersee               Madge
# 174                              Mayor Undersee               Mayor
# 175                                       Venia               Venia

# %% [markdown]
# ## Get named entity list per sentence

# %%
sent_entity_df = get_ne_list_per_sentence(combined_doc)
sent_entity_df
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\camil\AppData\Local\Temp\ipykernel_21928\2356371432.py", line 1, in <module>
#     sent_entity_df = get_ne_list_per_sentence(combined_doc)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\lib/utils\functions.py", line 48, in get_ne_list_per_sentence
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "c:\Users\camil\Documents\github\0the-hunger-games-network\venv\Lib\site-packages\executing\executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
sent_entity_df = []

# Loop through sentences, store named entity list for each sentence
for sent in combined_doc.sents:
    entity_list = [ent.text for ent in sent.ents]
    sent_entity_df.append({"sentence": sent, "entities": entity_list})

sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
len(combined_doc.ents)
# Out:
# 12403

# %% [markdown]
# ## Filter entities

# %%
sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(lambda x: filter_entity(x, character_df))

# Filter out sentences that don't have any character entities
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].map(len) > 0]
sent_entity_df_filtered.head(10)
# Out:
# Empty DataFrame
# Columns: [sentence, entities, character_entities]
# Index: []
